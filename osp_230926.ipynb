# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/OSP23Fall/
# Out:
# /content/drive/MyDrive/OSP23Fall

# %%
cd /content/drive/MyDrive/OSP23Fall/OpenSourceProgramming_Class2023/
# Out:
# /content/drive/MyDrive/OSP23Fall/OpenSourceProgramming_Class2023

# %%
# !git pull
# Out:
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), 1.33 KiB | 45.00 KiB/s, done.
# From https://github.com/NaeheonLee/OpenSourceProgramming_Class2023
#    7a4c52a..1a02be3  main       -> origin/main
# There is no tracking information for the current branch.
# Please specify which branch you want to merge with.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=origin/<branch> origin

# %%
# !git branch --set-upstream-to=origin/main origin
# Out:
# Branch 'origin' set up to track remote branch 'main' from 'origin'.

# %%
# !git pull
# Out:
# Updating 40c102e..1a02be3
# Fast-forward
#  test.py | 4 +++-
#  1 file changed, 3 insertions(+), 1 deletion(-)

# %%
# !git push -u origin main:osp07
# Out:
# Total 0 (delta 0), reused 0 (delta 0), pack-reused 0
# remote:
# remote: Create a pull request for 'osp07' on GitHub by visiting:
# remote:      https://github.com/NaeheonLee/OpenSourceProgramming_Class2023/pull/new/osp07
# remote:
# To https://github.com/NaeheonLee/OpenSourceProgramming_Class2023.git
#  * [new branch]      main -> osp07
# Branch 'main' set up to track remote branch 'osp07' from 'origin'.

# %%
# !git status
# Out:
# On branch origin
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	osp_230926.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add osp_230926.ipynb
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git clone https://NaeheonLee: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@github.com/NaeheonLee/OpenSourceProgramming_Class2023.git
# Out:
# fatal: destination path 'OpenSourceProgramming_Class2023' already exists and is not an empty directory.
